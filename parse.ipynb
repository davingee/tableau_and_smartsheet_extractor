# %%
import importlib
import open_ai_api

importlib.reload(open_ai_api)

# %%
# Smartsheet dashboard → output/YYYY-MM-DD/cbps_dashboard.json
cbps_data = await open_ai_api.get_cbps_data()

# %%
# Tableau latest report → output/YYYY-MM-DD/crosstab.csv + covered_building_count_by_tiers.csv
cbcbt_data = await open_ai_api.get_cbcbt_data()

# Specific report:
# cbcbt_data = await open_ai_api.get_cbcbt_data('Dec 31 2025')
